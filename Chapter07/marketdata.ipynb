# %% [markdown]
# # yahoofinancials

# %%
from yahoofinancials import YahooFinancials

# %% [markdown]
# ## Single-ticker Retrieval

# %%
aapl = YahooFinancials('AAPL')

# %% [markdown]
# ### Historical Data Retrieval

# %%
hist = aapl.get_historical_price_data('2020-01-01', '2020-12-31', 'daily')
print(hist)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/anaconda3/envs/trading_env/lib/python3.10/site-packages/yahoofinancials/data.py:567, in YahooFinanceData._retry_create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     566 try:
# --> 567     out = self._create_dict_ent(up_ticker, statement_type, tech_type, report_name, hist_obj)
#     568     return out
#
# File /opt/anaconda3/envs/trading_env/lib/python3.10/site-packages/yahoofinancials/data.py:528, in YahooFinanceData._create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     527 try:
# --> 528     cleaned_re_data = self._recursive_api_request(hist_obj, up_ticker)
#     529 except KeyError:
#
# ...

# %%
hist = aapl.get_historical_price_data('2020-01-01', '2020-12-31', 'weekly')
print(hist)
# Out:
# {'AAPL': {'eventsData': {}}}

# %%
hist = aapl.get_historical_price_data('2020-01-01', '2020-12-31', 'monthly')
print(hist)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/yahoofinancials/data.py:567, in YahooFinanceData._retry_create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     566 try:
# --> 567     out = self._create_dict_ent(up_ticker, statement_type, tech_type, report_name, hist_obj)
#     568     return out
#
# File /opt/anaconda3/lib/python3.12/site-packages/yahoofinancials/data.py:528, in YahooFinanceData._create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     527 try:
# --> 528     cleaned_re_data = self._recursive_api_request(hist_obj, up_ticker)
#     529 except KeyError:
#
# File /opt/anaconda3/lib/python3.12/site-packages/yahoofinancials/data.py:510, in YahooFinanceData._recursive_api_request(self, hist_obj, up_ticker, clean, i)
#     509 if clean:
# ...

# %%
import json
json_string = '{"AAPL":{"eventsData":{"dividends":{"2020-02-05":{"amount":0.1925,"date":1581085800,"formatted_date":"2020-02-07"},"2020-05-06":{"amount":0.205,"date":1588944600,"formatted_date":"2020-05-08"},"2020-08-05":{"amount":0.205,"date":1596807000,"formatted_date":"2020-08-07"},"2020-11-04":{"amount":0.205,"date":1604673000,"formatted_date":"2020-11-06"}},"splits":{"2020-08-26":{"date":1598880600,"numerator":4,"denominator":1,"splitRatio":"4:1","formatted_date":"2020-08-31"}}},"firstTradeDate":{"formatted_date":"1980-12-12","date":345479400},"currency":"USD","instrumentType":"EQUITY","timeZone":{"gmtOffset":-14400},"prices":[{"date":1577854800,"high":75.2249984741211,"low":73.1875,"open":74.05999755859375,"close":74.59750366210938,"volume":509062400,"adjclose":73.84844207763672,"formatted_date":"2020-01-01"},{"date":1578459600,"high":79.39250183105469,"low":74.29000091552734,"open":74.29000091552734,"close":78.16999816894531,"volume":726318800,"adjclose":77.38506317138672,"formatted_date":"2020-01-08"},{"date":1579064400,"high":79.75499725341797,"low":77.38749694824219,"open":77.9625015258789,"close":79.14250183105469,"volume":479412400,"adjclose":78.3478012084961,"formatted_date":"2020-01-15"},{"date":1579669200,"high":80.8324966430664,"low":76.22000122070312,"open":79.6449966430664,"close":79.42250061035156,"volume":677016
date":"2020-09-30"},{"date":1602043200,"high":125.38999938964844,"low":114.12999725341797,"open":114.62000274658203,"close":121.0999984741211,"volume":783390400,"adjclose":120.71104431152344,"formatted_date":"2020-10-07"},{"date":1602648000,"high":123.02999877929688,"low":115.62999725341797,"open":121.0,"close":117.51000213623047,"volume":624078300,"adjclose":117.1325912475586,"formatted_date":"2020-10-14"},{"date":1603252800,"high":118.70999908447266,"low":112.87999725341797,"open":116.66999816894531,"close":116.5999984741211,"volume":478634100,"adjclose":116.22550964355469,"formatted_date":"2020-10-21"},{"date":1603857600,"high":116.93000030517578,"low":107.31999969482422,"open":115.05000305175781,"close":110.44000244140625,"volume":710830900,"adjclose":110.08528900146484,"formatted_date":"2020-10-28"},{"date":1604466000,"high":121.98999786376953,"low":112.3499984741211,"open":114.13999938964844,"close":115.97000122070312,"volume":671619200,"adjclose":115.5975341796875,"formatted_date":"2020-11-04"},{"date":1605070800,"high":120.98999786376953,"low":116.44000244140625,"open":117.19000244140625,"close":119.38999938964844,"volume":462493200,"adjclose":119.21186065673828,"formatted_date":"2020-11-11"},{"date":1605675600,"high":119.81999969482422,"low":112.58999633789062,"open":118.61000061035156,"close":115.16999816894531,"volume":465872900,"adjclose":114.99815368652344,"formatted_date":"2020-11-18"},{"date":1606280400,"high":123.47000122070312,"low":115.16999816894531,"open":115.55000305175781,"close":122.72000122070312,"volume":420767500,"adjclose":122.53689575195312,"formatted_date":"2020-11-25"},{"date":1606885200,"high":124.9800033569336,"low":120.88999938964844,"open":122.0199966430664,"close":124.37999725341797,"volume":415169700,"adjclose":124.19441223144531,"formatted_date":"2020-12-02"},{"date":1607490000,"high":127.9000015258789,"low":120.1500015258789,"open":124.52999877929688,"close":127.87999725341797,"volume":520098000,"adjclose":127.6891860961914,"formatted_date":"2020-12-09"},{"date":1608094800,"high":134.41000366210938,"low":123.44999694824219,"open":127.41000366210938,"close":131.8800048828125,"volume":675266300,"adjclose":131.6832275390625,"formatted_date":"2020-12-16"},{"date":1608699600,"high":138.7899932861328,"low":130.77999877929688,"open":132.16000366210938,"close":134.8699951171875,"volume":388687300,"adjclose":134.66876220703125,"formatted_date":"2020-12-23"},{"date":1609304400,"high":135.99000549316406,"low":133.39999389648438,"open":135.5800018310547,"close":133.72000122070312,"volume":96452100,"adjclose":133.52047729492188,"formatted_date":"2020-12-30"}]}}'

hist = json.loads(json_string)

# %%
import pandas as pd
pd.set_option('display.max_columns', 7)
hist_df = pd.DataFrame(hist['AAPL']['prices']).drop('date', axis=1).set_index('formatted_date')

hist_df
# Out:
#                       high         low        open       close      volume  \
# formatted_date
# 2020-01-01       75.224998   73.187500   74.059998   74.597504   509062400
# 2020-01-08       79.392502   74.290001   74.290001   78.169998   726318800
# 2020-01-15       79.754997   77.387497   77.962502   79.142502   479412400
# 2020-01-22       80.832497   76.220001   79.644997   79.422501   677016000
# 2020-01-29       81.962502   75.555000   81.112503   79.712502   853162800
# 2020-02-05       81.305000   78.462502   80.879997   79.902496   545608400
# 2020-02-12       81.805000   78.652496   80.367500   79.750000   441122800
# 2020-02-19       81.162498   71.532501   80.000000   72.019997   776972800
# 2020-02-26       76.000000   64.092499   71.632500   72.330002  1606418000
# 2020-03-04       75.849998   65.750000   74.110001   71.334999  1204962800
# 2020-03-11       70.305000   59.599998   69.347504   63.215000  1691284400
# ...

# %% [markdown]
# ### Real-time Data Retrieval

# %%
print(aapl.get_stock_price_data())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/yahoofinancials/data.py:567, in YahooFinanceData._retry_create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     566 try:
# --> 567     out = self._create_dict_ent(up_ticker, statement_type, tech_type, report_name, hist_obj)
#     568     return out
#
# File /opt/anaconda3/lib/python3.12/site-packages/yahoofinancials/data.py:557, in YahooFinanceData._create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     556 try:
# --> 557     re_data = self._get_historical_data(YAHOO_URL, r_map, tech_type, statement_type)
#     558 except KeyError:
#
# File /opt/anaconda3/lib/python3.12/site-packages/yahoofinancials/data.py:277, in YahooFinanceData._get_historical_data(self, url, config, tech_type, statement_type)
# ...

# %% [markdown]
# ### Financial Statements Retrieval

# %%
statements = aapl.get_financial_stmts('quarterly', ['income', 'cash', 'balance'])
print(statements)
# Out:
# {'incomeStatementHistoryQuarterly': {'AAPL': [{'2020-12-26': {'researchDevelopment': 5163000000, 'effectOfAccountingCharges': None, 'incomeBeforeTax': 33579000000, 'minorityInterest': None, 'netIncome': 28755000000, 'sellingGeneralAdministrative': 5631000000, 'grossProfit': 44328000000, 'ebit': 33534000000, 'operatingIncome': 33534000000, 'otherOperatingExpenses': None, 'interestExpense': -638000000, 'extraordinaryItems': None, 'nonRecurring': None, 'otherItems': None, 'incomeTaxExpense': 4824000000, 'totalRevenue': 111439000000, 'totalOperatingExpenses': 77905000000, 'costOfRevenue': 67111000000, 'totalOtherIncomeExpenseNet': 45000000, 'discontinuedOperations': None, 'netIncomeFromContinuingOps': 28755000000, 'netIncomeApplicableToCommonShares': 28755000000}}, {'2020-09-26': {'researchDevelopment': 4978000000, 'effectOfAccountingCharges': None, 'incomeBeforeTax': 14901000000, 'minorityInterest': None, 'netIncome': 12673000000, 'sellingGeneralAdministrative': 4936000000, 'grossProfit
# ...

# %% [markdown]
# ### Summary Data Retrieval

# %%
print(aapl.get_summary_data())
# Out:
# {'AAPL': {'previousClose': 120.53, 'regularMarketOpen': 119.9, 'twoHundredDayAverage': 123.023506, 'trailingAnnualDividendYield': 0.0066954284, 'payoutRatio': 0.2177, 'volume24Hr': None, 'regularMarketDayHigh': 121.43, 'navPrice': None, 'averageDailyVolume10Day': 106041200, 'totalAssets': None, 'regularMarketPreviousClose': 120.53, 'fiftyDayAverage': 127.73088, 'trailingAnnualDividendRate': 0.807, 'open': 119.9, 'toCurrency': None, 'averageVolume10days': 106041200, 'expireDate': '-', 'yield': None, 'algorithm': None, 'dividendRate': 0.82, 'exDividendDate': '2021-02-05', 'beta': 1.251354, 'circulatingSupply': None, 'startDate': '-', 'regularMarketDayLow': 119.675, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 32.54407, 'regularMarketVolume': 185549522, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 2014404149248, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 110580441, 'priceToSalesTrailing12Months': 6.84857, 'dayLow': 119.675, 'ask':
# ...

# %% [markdown]
# ## Multiple-tickers Retrieval

# %% [markdown]
# ## Historical Data Retrieval

# %%
currencies = YahooFinancials(['EURCHF=X', 'USDEUR=X', 'GBPUSD=x'])
print(currencies.get_historical_price_data('2020-01-01','2020-12-31', 'weekly'))
# Out:
# {'EURCHF=X': {'eventsData': {}, 'firstTradeDate': {'formatted_date': '2003-01-23', 'date': 1043280000}, 'currency': 'CHF', 'instrumentType': 'CURRENCY', 'timeZone': {'gmtOffset': 0}, 'prices': [{'date': 1577836800, 'high': 1.0877000093460083, 'low': 1.0818699598312378, 'open': 1.0872000455856323, 'close': 1.084280014038086, 'volume': 0, 'adjclose': 1.084280014038086, 'formatted_date': '2020-01-01'}, {'date': 1578441600, 'high': 1.083299994468689, 'low': 1.0758999586105347, 'open': 1.080530047416687, 'close': 1.0809999704360962, 'volume': 0, 'adjclose': 1.0809999704360962, 'formatted_date': '2020-01-08'}, {'date': 1579046400, 'high': 1.0774999856948853, 'low': 1.0729299783706665, 'open': 1.076300024986267, 'close': 1.0744800567626953, 'volume': 0, 'adjclose': 1.0744800567626953, 'formatted_date': '2020-01-15'}, {'date': 1579651200, 'high': 1.0786099433898926, 'low': 1.0664700269699097, 'open': 1.0739500522613525, 'close': 1.068600058555603, 'volume': 0, 'adjclose': 1.068600058555603, 
# ...

# %% [markdown]
# # pandas_datareader

# %%
from pandas_datareader import data
start_date = '2010-01-01'
end_date = '2020-12-31'

# %% [markdown]
# ## Access to Yahoo Finance

# %%
aapl = data.DataReader('AAPL', 'yahoo', start_date, end_date)
aapl
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 aapl = data.DataReader('AAPL', 'yahoo', start_date, end_date)
#       2 aapl
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas_datareader/data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
# ...

# %% [markdown]
# ## Access to EconDB

# %%
oilprodus = data.DataReader('ticker=OILPRODUS', 'econdb', start_date, end_date)
oilprodus
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 oilprodus = data.DataReader('ticker=OILPRODUS', 'econdb', start_date, end_date)
#       2 oilprodus
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas_datareader/data.py:659, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     640     return AVTimeSeriesReader(
#     641         symbols=name,
#     642         function="TIME_SERIES_INTRADAY",
#    (...)
#     648         api_key=api_key,
#     649     ).read()
#     651 elif data_source == "econdb":
# ...

# %% [markdown]
# ## Access to Fed's Fred

# %%
import pandas as pd
pd.set_option('display.max_rows', 2)

gdp = data.DataReader('GDP', 'fred', start_date, end_date)
gdp
# Out:
#                   GDP
# DATE
# 2010-01-01  14764.610
# ...               ...
# 2020-10-01  22068.767
#
# [44 rows x 1 columns]

# %%
gs10 = data.get_data_fred('GS20')
gs10
# Out:
#             GS20
# DATE
# 2016-04-01  2.21
# ...          ...
# 2021-02-01  1.88
#
# [59 rows x 1 columns]

# %% [markdown]
# ## Caching Queries

# %%
import datetime
import requests_cache
session = requests_cache.CachedSession(cache_name='cache', backend='sqlite', expire_after=datetime.timedelta(days=7))

aapl_full_history = data.DataReader("AAPL", 'yahoo', datetime.datetime(1980, 1, 1), datetime.datetime(2020, 12, 31), session=session)
aapl_full_history
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 1980-12-12    0.128906    0.128348    0.128348    0.128348  469033600.0
# ...                ...         ...         ...         ...          ...
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   99116600.0
#
#              Adj Close
# Date
# 1980-12-12    0.100922
# ...                ...
# 2020-12-31  132.492020
#
# [10099 rows x 6 columns]

# %%
aapl_full_history.loc['2013-01-07']
# Out:
# High         18.903570
#                ...
# Adj Close    16.259851
# Name: 2013-01-07 00:00:00, Length: 6, dtype: float64

# %% [markdown]
# # Quandl

# %%
import quandl
import os

quandl.ApiConfig.api_key = '466YsoWfy2U-eavX4X4G'

# %%
papple = quandl.get('ODA/PAPPLE_USD')
papple
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/trading_env/lib/python3.10/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/anaconda3/envs/trading_env/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...

# %%
aapl_fundamental_data = quandl.get_table('ZACKS/FC', ticker='AAPL')
aapl_fundamental_data
# Out:
#      m_ticker ticker  comp_name       ...       wavg_shares_out_diluted  \
# None                                  ...
# 0        AAPL   AAPL  APPLE INC       ...                      20000.44
# ...       ...    ...        ...       ...                           ...
# 4        AAPL   AAPL  APPLE INC       ...                      19093.01
#
#      eps_basic_net eps_diluted_net
# None
# 0            3.000           2.980
# ...            ...             ...
# 4            1.055           1.045
#
# [5 rows x 249 columns]

# %% [markdown]
# # IEX Cloud

# %%
from iexfinance.refdata import get_symbols
get_symbols(output_format='pandas', token=os.environ["IEX_TOKEN"])
# Out:
#               cik currency        date ...  region symbol type
# 0      0001090872      USD  2021-03-20 ...      US      A   cs
# ...           ...      ...         ... ...     ...    ...  ...
# 10193  0000846475      USD  2021-03-20 ...      US   ZYXI   cs
#
# [10194 rows x 14 columns]

# %%
from iexfinance.stocks import Stock
aapl = Stock("aapl", token=os.environ["IEX_TOKEN"])
aapl.get_balance_sheet()
# Out:
#            accountsPayable capitalSurplus  commonStock      ...        \
# 2021-01-28     63846000000           None  16935119000      ...
#
#                subkey           date        updated
# 2021-01-28  quarterly  1608940800000  1612292383000
#
# [1 rows x 38 columns]

# %%
from iexfinance.stocks import get_sector_performance
get_sector_performance(output_format='pandas', token=os.environ["IEX_TOKEN"])
# Out:
#                           lastUpdated                    name performance  \
# Communication Services  1616184000229  Communication Services     0.00869
# ...                               ...                     ...         ...
# Utilities               1616184000042               Utilities     0.00274
#
#                           type
# Communication Services  sector
# ...                        ...
# Utilities               sector
#
# [11 rows x 4 columns]

# %%
aapl.get_price()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-9e025199ccda> in <module>
# ----> 1 aapl.get_price()
#
# d:\anaconda3\envs\handson-algorithmic-trading-with-python\lib\site-packages\iexfinance\stocks\base.py in get_price(self)
#     320             return pd.DataFrame.from_dict(out, orient="index", columns=["price"])
#     321
# --> 322         return self._get_endpoint("price", format=format)
#     323
#     324     def get_quote(self, **kwargs):
#
# d:\anaconda3\envs\handson-algorithmic-trading-with-python\lib\site-packages\iexfinance\stocks\base.py in _get_endpoint(self, endpoint, params, format, filter_)
#      83             else:
#      84                 result[symbol] = data[symbol][endpoint]
# ---> 85         return self._output_format_one(result, format=format)
#      86
#      87     def _get_field(self, endpoint, field):
#
# ...

# %%
from iexfinance.stocks import get_historical_data

get_historical_data("AAPL", start="20190101", end="20200101",output_format='pandas', token=os.environ["IEX_TOKEN"])
# Out:
#             change changeOverTime changePercent    ...       uVolume  \
# 2019-01-02   0.045       0.491077        0.0011    ...      37039737
# ...            ...            ...           ...    ...           ...
# 2019-12-31  0.5325        1.77264        0.0073    ...      25247625
#
#                   updated     volume
# 2019-01-02  1612491365000  148158948
# ...                   ...        ...
# 2019-12-31  1612491469000  100990500
#
# [252 rows x 25 columns]

# %% [markdown]
# # MarketStack

# %%
import requests
import os

params = {
  'access_key': os.environ['MarketStack_Access_Key']
}

api_result = requests.get('http://api.marketstack.com/v1/tickers/aapl/eod', params)

api_response = api_result.json()
print(f"Symbol = {api_response['data']['symbol']}")
for eod in api_response['data']['eod']:
    print(f"{eod['date']}: {eod['adj_close']}")
# Out:
# Symbol = AAPL
# 2021-03-19T00:00:00+0000: 119.99
# 2021-03-18T00:00:00+0000: 120.53
# 2021-03-17T00:00:00+0000: 124.76
# 2021-03-16T00:00:00+0000: 125.57
# 2021-03-15T00:00:00+0000: 123.99
# 2021-03-12T00:00:00+0000: 121.03
# 2021-03-11T00:00:00+0000: 121.96
# 2021-03-10T00:00:00+0000: 119.98
# 2021-03-09T00:00:00+0000: 121.09
# 2021-03-08T00:00:00+0000: 116.36
# 2021-03-05T00:00:00+0000: 121.42
# 2021-03-04T00:00:00+0000: 120.13
# 2021-03-03T00:00:00+0000: 122.06
# 2021-03-02T00:00:00+0000: 125.12
# 2021-03-01T00:00:00+0000: 127.79
# 2021-02-26T00:00:00+0000: 121.26
# 2021-02-25T00:00:00+0000: 120.99
# 2021-02-24T00:00:00+0000: 125.35
# 2021-02-23T00:00:00+0000: 125.86
# 2021-02-22T00:00:00+0000: 126.0
# 2021-02-19T00:00:00+0000: 129.87
# 2021-02-18T00:00:00+0000: 129.71
# 2021-02-17T00:00:00+0000: 130.84
# 2021-02-16T00:00:00+0000: 133.19
# 2021-02-12T00:00:00+0000: 135.37
# 2021-02-11T00:00:00+0000: 135.13
# 2021-02-10T00:00:00+0000: 135.39
# 2021-02-09T00:00:00+0000: 136.01
# ...

# %%
api_result = requests.get('http://api.marketstack.com/v1/exchanges/XNAS/tickers', params)

api_response = api_result.json()

print(f"Exchange Name = {api_response['data']['name']}")
for ticker in api_response['data']['tickers']:
    print(f"{ticker['name']}: {ticker['symbol']}")
# Out:
# Exchange Name = NASDAQ Stock Exchange
# Microsoft Corporation: MSFT
# Apple Inc: AAPL
# Amazon.com Inc: AMZN
# Alphabet Inc - Class C: GOOG
# Alphabet Inc - Class A: GOOGL
# Facebook Inc - Class A: FB
# Vodafone Group plc: VOD
# Intel Corp: INTC
# Comcast Corp - Class A: CMCSA
# PepsiCo Inc: PEP
# Adobe Inc: ADBE
# Cisco Systems Inc: CSCO
# NVIDIA Corp: NVDA
# NetFlix Inc: NFLX
# Tesla Inc: TSLA
# Costco Wholesale Corp: COST
# PayPal Holdings Inc: PYPL
# AMGEN Inc: AMGN
# Sanofi: SNY
# ASML Holding NV: ASML
# Broadcom Inc: AVGO
# Texas Instruments Inc: TXN
# Charter Communications Inc - Class A: CHTR
# Starbucks Corp: SBUX
# Gilead Sciences Inc: GILD
# Qualcomm Inc: QCOM
# T-Mobile US Inc: TMUS
# Mondelez International Inc - Class A: MDLZ
# Fiserv Inc: FISV
# CME Group Inc - Class A: CME
# Intuit Inc: INTU
# Booking Holdings Inc: BKNG
# Automatic Data Processing Inc: ADP
# Intuitive Surgical Inc: ISRG
# Vertex Pharmaceuticals Inc: VRTX
# Micron Technology Inc: MU
# ...
